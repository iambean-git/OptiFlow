# %%
from preamble import *
from sklearn.model_selection import train_test_split, cross_val_score, KFold
from sklearn.metrics import mean_squared_error
import xgboost as xgb

# %%
df = pd.read_csv('./data/j_before_feature_importance.csv')

# %%
def create_sequences(data, seq_length, target_length):
  Xs = []
  ys = []
  for i in range(len(data) - seq_length - target_length + 1):
    X = data[i:(i + seq_length)].drop('outflow', axis=1).values
    y = data['outflow'].values[i + seq_length: i+ seq_length + target_length]
    Xs.append(X)
    ys.append(y)
  return np.array(Xs), np.array(ys)

# %%
SEQ_LENGTH = 168  # 과거 7일 (시간 단위)
TARGET_LENGTH = 1 # 이후 1시간 예측

X, y = create_sequences(df, SEQ_LENGTH, TARGET_LENGTH)

# %%
train_size = int(len(X) * 0.7)
valid_size = int(train_size * 0.1)

X_train, X_test = X[:(train_size - valid_size)], X[train_size:]
X_valid, y_valid = X[(train_size - valid_size):train_size], y[(train_size - valid_size):train_size]
y_train, y_test = y[:(train_size - valid_size)], y[train_size:]

print(X_train.shape, X_test.shape, X_valid.shape, y_train.shape, y_valid.shape, y_test.shape)
# Out:
# (9674, 168, 32) (4607, 168, 32) (1074, 168, 32) (9674, 1) (1074, 1) (4607, 1)

# %%
import xgboost as xgb

def get_feature_importance(X_train, y_train, X_valid, y_valid, feature_names):
  reg = xgb.XGBRegressor(n_estimators=1000, eval_metric="rmse", random_state=1021, early_stopping_rounds=25)
  reg.fit(
    X_train.reshape(X_train.shape[0], -1), 
    y_train.reshape(-1),
    eval_set=[(X_valid.reshape(X_valid.shape[0], -1), y_valid.reshape(-1))],
    verbose=10,
  )
  feature_importances = reg.feature_importances_
  
  # 순서에 맞게 feature name을 확장
  feature_names_extended = []
  for i in range(SEQ_LENGTH):
    for name in feature_names:
      feature_names_extended.append(f"{name}_t-{SEQ_LENGTH-i-1}")
          
  importance_df = pd.DataFrame({'Feature': feature_names_extended, 'Importance': feature_importances})
  importance_df = importance_df.sort_values('Importance', ascending=False)
  return reg, importance_df

# %%
feature_names = df.drop('outflow', axis=1).columns
reg_all, importance_df = get_feature_importance(X_train, y_train, X_valid, y_valid, feature_names)
# Out:
# [0]	validation_0-rmse:2007.90261
# [10]	validation_0-rmse:1222.75470
# [20]	validation_0-rmse:1209.28441
# [30]	validation_0-rmse:1216.90246
# [40]	validation_0-rmse:1231.06637
# [41]	validation_0-rmse:1231.71829

# %%
# 중요도 시각화 (상위 N개만)
N = 20 
plt.figure(figsize=(10, 6))
plt.bar(importance_df['Feature'][:N], importance_df['Importance'][:N])
plt.xticks(rotation=90)
plt.xlabel('Feature')
plt.ylabel('Importance')
plt.title('Top {} Feature Importances'.format(N))
plt.tight_layout()
plt.show()

# %%
# 중요도가 평균 이상인 feature만 선택
mean_importance = importance_df['Importance'].mean()
selected_features = importance_df[importance_df['Importance'] >= mean_importance]['Feature'].tolist()
print(f"Number of features selected: {len(selected_features)}")
# Out:
# Number of features selected: 989

# %%
def select_features(X, selected_features, feature_names, seq_length):
  selected_indices = []
  num_features = len(feature_names)
  total_features = seq_length * num_features  # 전체 feature 수 (time step * feature)

  for feature in selected_features:
    feature_name, time_lag_str = feature.split('_t-')
    time_lag = int(time_lag_str)
    feature_index = feature_names.get_loc(feature_name)

    # time lag에 따른 offset 계산
    time_offset = time_lag * num_features
    
    # 최종 인덱스 계산 (feature 시작 위치 + feature_index)
    index = total_features - time_offset - num_features + feature_index #  역순으로

    if index >= X.shape[2] or index < 0:
      print(f"Warning: Index {index} out of bounds for feature {feature}. Skipping.")
      continue
    selected_indices.append(index)

  return X[:, :, selected_indices]

# %%
X_train_selected = select_features(X_train, selected_features, feature_names, SEQ_LENGTH)
X_valid_selected = select_features(X_valid, selected_features, feature_names, SEQ_LENGTH)
X_test_selected = select_features(X_test, selected_features, feature_names, SEQ_LENGTH)

print("Selected feature X train shape:", X_train_selected.shape)
print("Selected feature X valid shape:", X_valid_selected.shape)
print("Selected feature X test shape:", X_test_selected.shape)
# Out:
# Warning: Index 5350 out of bounds for feature input_t-0. Skipping.
# Warning: Index 5318 out of bounds for feature input_t-1. Skipping.
# Warning: Index 78 out of bounds for feature hour_t-165. Skipping.
# Warning: Index 590 out of bounds for feature hour_t-149. Skipping.
# Warning: Index 110 out of bounds for feature hour_t-164. Skipping.
# Warning: Index 5368 out of bounds for feature rolling_3h_avg_t-0. Skipping.
# Warning: Index 5369 out of bounds for feature rolling_6h_max_t-0. Skipping.
# Warning: Index 3226 out of bounds for feature rolling_6h_avg_t-67. Skipping.
# Warning: Index 5374 out of bounds for feature delta_24h_t-0. Skipping.
# Warning: Index 800 out of bounds for feature temperature_t-142. Skipping.
# Warning: Index 142 out of bounds for feature hour_t-163. Skipping.
# Warning: Index 3258 out of bounds for feature rolling_6h_avg_t-66. Skipping.
# Warning: Index 5372 out of bounds for feature change_rate_1h_t-0. Skipping.
# Warning: Index 5273 out of bounds for feature rolling_6h_max_t-3. Skipping.
# Warning: Index 3710 out of bounds for feature delta_24h_t-52. Skipping.
# Warning: Index 174 out of bounds for feature hour_t-162. Skipping.
# Warning: Index 5375 out of bounds for feature daily_range_lag_1d_t-0. Skipping.
# Warning: Index 4378 out of bounds for feature rolling_6h_avg_t-31. Skipping.
# Warning: Index 4664 out of bounds for feature rolling_3h_avg_t-22. Skipping.
# Warning: Index 5183 out of bounds for feature daily_range_lag_1d_t-6. Skipping.
# Warning: Index 5363 out of bounds for feature lag_1h_t-0. Skipping.
# Warning: Index 4856 out of bounds for feature rolling_3h_avg_t-16. Skipping.
# Warning: Index 5208 out of bounds for feature rolling_3h_avg_t-5. Skipping.
# Warning: Index 5340 out of bounds for feature change_rate_1h_t-1. Skipping.
# Warning: Index 1911 out of bounds for feature lag_168h_t-108. Skipping.
# Warning: Index 2334 out of bounds for feature delta_24h_t-95. Skipping.
# Warning: Index 2458 out of bounds for feature rolling_6h_avg_t-91. Skipping.
# Warning: Index 4761 out of bounds for feature rolling_6h_max_t-19. Skipping.
# Warning: Index 4678 out of bounds for feature input_t-21. Skipping.
# Warning: Index 5178 out of bounds for feature rolling_6h_avg_t-6. Skipping.
# Warning: Index 5286 out of bounds for feature input_t-2. Skipping.
# Warning: Index 1687 out of bounds for feature lag_168h_t-115. Skipping.
# Warning: Index 1440 out of bounds for feature temperature_t-122. Skipping.
# Warning: Index 920 out of bounds for feature rolling_3h_avg_t-139. Skipping.
# Warning: Index 5151 out of bounds for feature daily_range_lag_1d_t-7. Skipping.
# Warning: Index 5119 out of bounds for feature daily_range_lag_1d_t-8. Skipping.
# Warning: Index 3923 out of bounds for feature lag_1h_t-45. Skipping.
# Warning: Index 3290 out of bounds for feature rolling_6h_avg_t-65. Skipping.
# Warning: Index 3524 out of bounds for feature atmospheric_pressure_t-57. Skipping.
# Warning: Index 3526 out of bounds for feature input_t-57. Skipping.
# Warning: Index 3447 out of bounds for feature lag_168h_t-60. Skipping.
# Warning: Index 2392 out of bounds for feature rolling_3h_avg_t-93. Skipping.
# Warning: Index 4698 out of bounds for feature rolling_6h_avg_t-21. Skipping.
# Warning: Index 4742 out of bounds for feature input_t-19. Skipping.
# Warning: Index 695 out of bounds for feature lag_168h_t-146. Skipping.
# Warning: Index 2394 out of bounds for feature rolling_6h_avg_t-93. Skipping.
# Warning: Index 4800 out of bounds for feature temperature_t-17. Skipping.
# Warning: Index 4730 out of bounds for feature rolling_6h_avg_t-20. Skipping.
# Warning: Index 5087 out of bounds for feature daily_range_lag_1d_t-9. Skipping.
# Warning: Index 5023 out of bounds for feature daily_range_lag_1d_t-11. Skipping.
# Warning: Index 4627 out of bounds for feature lag_1h_t-23. Skipping.
# Warning: Index 5336 out of bounds for feature rolling_3h_avg_t-1. Skipping.
# Warning: Index 3244 out of bounds for feature dayofyear_t-66. Skipping.
# Warning: Index 2816 out of bounds for feature temperature_t-79. Skipping.
# Warning: Index 921 out of bounds for feature rolling_6h_max_t-139. Skipping.
# Warning: Index 4819 out of bounds for feature lag_1h_t-17. Skipping.
# Warning: Index 480 out of bounds for feature temperature_t-152. Skipping.
# Warning: Index 988 out of bounds for feature change_rate_1h_t-137. Skipping.
# Warning: Index 5171 out of bounds for feature lag_1h_t-6. Skipping.
# Warning: Index 2426 out of bounds for feature rolling_6h_avg_t-92. Skipping.
# Warning: Index 5242 out of bounds for feature rolling_6h_avg_t-4. Skipping.
# Warning: Index 4962 out of bounds for feature wind_speed_t-12. Skipping.
# Warning: Index 2019 out of bounds for feature humidity_t-104. Skipping.
# Warning: Index 1926 out of bounds for feature input_t-107. Skipping.
# Warning: Index 5306 out of bounds for feature rolling_6h_avg_t-2. Skipping.
# Warning: Index 3322 out of bounds for feature rolling_6h_avg_t-64. Skipping.
# Warning: Index 1212 out of bounds for feature change_rate_1h_t-130. Skipping.
# Warning: Index 2016 out of bounds for feature temperature_t-104. Skipping.
# Warning: Index 2808 out of bounds for feature rolling_3h_avg_t-80. Skipping.
# Warning: Index 3678 out of bounds for feature delta_24h_t-53. Skipping.
# Warning: Index 2199 out of bounds for feature lag_168h_t-99. Skipping.
# Warning: Index 3288 out of bounds for feature rolling_3h_avg_t-65. Skipping.
# Warning: Index 5085 out of bounds for feature rolling_7d_std_t-9. Skipping.
# Warning: Index 5062 out of bounds for feature input_t-9. Skipping.
# Warning: Index 1443 out of bounds for feature humidity_t-122. Skipping.
# Warning: Index 5055 out of bounds for feature daily_range_lag_1d_t-10. Skipping.
# Warning: Index 2046 out of bounds for feature delta_24h_t-104. Skipping.
# Warning: Index 5299 out of bounds for feature lag_1h_t-2. Skipping.
# Warning: Index 3906 out of bounds for feature wind_speed_t-45. Skipping.
# Warning: Index 5254 out of bounds for feature input_t-3. Skipping.
# Warning: Index 571 out of bounds for feature rolling_24h_max_t-150. Skipping.
# Warning: Index 2489 out of bounds for feature rolling_6h_max_t-90. Skipping.
# Warning: Index 2451 out of bounds for feature lag_1h_t-91. Skipping.
# Warning: Index 4922 out of bounds for feature rolling_6h_avg_t-14. Skipping.
# Warning: Index 1306 out of bounds for feature rolling_6h_avg_t-127. Skipping.
# Warning: Index 855 out of bounds for feature lag_168h_t-141. Skipping.
# Warning: Index 4571 out of bounds for feature rolling_24h_max_t-25. Skipping.
# Warning: Index 3334 out of bounds for feature input_t-63. Skipping.
# Warning: Index 793 out of bounds for feature rolling_6h_max_t-143. Skipping.
# Warning: Index 4995 out of bounds for feature humidity_t-11. Skipping.
# Warning: Index 258 out of bounds for feature wind_speed_t-159. Skipping.
# Warning: Index 4058 out of bounds for feature rolling_6h_avg_t-41. Skipping.
# Warning: Index 665 out of bounds for feature rolling_6h_max_t-147. Skipping.
# Warning: Index 3987 out of bounds for feature lag_1h_t-43. Skipping.
# Warning: Index 1155 out of bounds for feature humidity_t-131. Skipping.
# Warning: Index 4569 out of bounds for feature rolling_6h_max_t-25. Skipping.
# Warning: Index 1020 out of bounds for feature change_rate_1h_t-136. Skipping.
# Warning: Index 4891 out of bounds for feature rolling_24h_max_t-15. Skipping.
# Warning: Index 5123 out of bounds for feature humidity_t-7. Skipping.
# Warning: Index 225 out of bounds for feature precipitation_t-160. Skipping.
# Warning: Index 2135 out of bounds for feature lag_168h_t-101. Skipping.
# Warning: Index 5209 out of bounds for feature rolling_6h_max_t-5. Skipping.
# Warning: Index 2811 out of bounds for feature rolling_24h_max_t-80. Skipping.
# Warning: Index 5179 out of bounds for feature rolling_24h_max_t-6. Skipping.
# Warning: Index 3831 out of bounds for feature lag_168h_t-48. Skipping.
# Warning: Index 5278 out of bounds for feature delta_24h_t-3. Skipping.
# Warning: Index 4027 out of bounds for feature rolling_24h_max_t-42. Skipping.
# Warning: Index 3415 out of bounds for feature lag_168h_t-61. Skipping.
# Warning: Index 3681 out of bounds for feature precipitation_t-52. Skipping.
# Warning: Index 2591 out of bounds for feature daily_range_lag_1d_t-87. Skipping.
# Warning: Index 2342 out of bounds for feature input_t-94. Skipping.
# Warning: Index 3782 out of bounds for feature input_t-49. Skipping.
# Warning: Index 2297 out of bounds for feature rolling_6h_max_t-96. Skipping.
# Warning: Index 3999 out of bounds for feature daily_range_lag_1d_t-43. Skipping.
# Warning: Index 3546 out of bounds for feature rolling_6h_avg_t-57. Skipping.
# Warning: Index 4019 out of bounds for feature lag_1h_t-42. Skipping.
# Warning: Index 5308 out of bounds for feature change_rate_1h_t-2. Skipping.
# Warning: Index 1273 out of bounds for feature rolling_6h_max_t-128. Skipping.
# Warning: Index 4710 out of bounds for feature input_t-20. Skipping.
# Warning: Index 3100 out of bounds for feature change_rate_1h_t-71. Skipping.
# Warning: Index 4952 out of bounds for feature rolling_3h_avg_t-13. Skipping.
# Warning: Index 2022 out of bounds for feature input_t-104. Skipping.
# Warning: Index 386 out of bounds for feature wind_speed_t-155. Skipping.
# Warning: Index 4646 out of bounds for feature input_t-22. Skipping.
# Warning: Index 57 out of bounds for feature rolling_6h_max_t-166. Skipping.
# Warning: Index 4348 out of bounds for feature change_rate_1h_t-32. Skipping.
# Warning: Index 3260 out of bounds for feature change_rate_1h_t-66. Skipping.
# Warning: Index 4511 out of bounds for feature daily_range_lag_1d_t-27. Skipping.
# Warning: Index 3622 out of bounds for feature input_t-54. Skipping.
# Warning: Index 3650 out of bounds for feature wind_speed_t-53. Skipping.
# Warning: Index 2366 out of bounds for feature delta_24h_t-94. Skipping.
# Warning: Index 4890 out of bounds for feature rolling_6h_avg_t-15. Skipping.
# Warning: Index 4988 out of bounds for feature change_rate_1h_t-12. Skipping.
# Warning: Index 3995 out of bounds for feature rolling_24h_max_t-43. Skipping.
# Warning: Index 4924 out of bounds for feature change_rate_1h_t-14. Skipping.
# Warning: Index 3582 out of bounds for feature delta_24h_t-56. Skipping.
# Warning: Index 186 out of bounds for feature rolling_6h_avg_t-162. Skipping.
# Warning: Index 1854 out of bounds for feature delta_24h_t-110. Skipping.
# Warning: Index 887 out of bounds for feature lag_168h_t-140. Skipping.
# Warning: Index 406 out of bounds for feature lag_24h_t-155. Skipping.
# Warning: Index 4518 out of bounds for feature input_t-26. Skipping.
# Warning: Index 2071 out of bounds for feature lag_168h_t-103. Skipping.
# Warning: Index 5220 out of bounds for feature atmospheric_pressure_t-4. Skipping.
# Warning: Index 2104 out of bounds for feature rolling_3h_avg_t-102. Skipping.
# Warning: Index 2552 out of bounds for feature rolling_3h_avg_t-88. Skipping.
# Warning: Index 5311 out of bounds for feature daily_range_lag_1d_t-2. Skipping.
# Warning: Index 3161 out of bounds for feature rolling_6h_max_t-69. Skipping.
# Warning: Index 2882 out of bounds for feature wind_speed_t-77. Skipping.
# Warning: Index 3068 out of bounds for feature change_rate_1h_t-72. Skipping.
# Warning: Index 1274 out of bounds for feature rolling_6h_avg_t-128. Skipping.
# Warning: Index 1619 out of bounds for feature lag_1h_t-117. Skipping.
# Warning: Index 857 out of bounds for feature rolling_6h_max_t-141. Skipping.
# Warning: Index 86 out of bounds for feature lag_24h_t-165. Skipping.
# Warning: Index 502 out of bounds for feature lag_24h_t-152. Skipping.
# Warning: Index 3769 out of bounds for feature rolling_6h_max_t-50. Skipping.
# Warning: Index 1625 out of bounds for feature rolling_6h_max_t-117. Skipping.
# Warning: Index 547 out of bounds for feature humidity_t-150. Skipping.
# Warning: Index 1752 out of bounds for feature rolling_3h_avg_t-113. Skipping.
# Warning: Index 2814 out of bounds for feature delta_24h_t-80. Skipping.
# Warning: Index 4316 out of bounds for feature change_rate_1h_t-33. Skipping.
# Warning: Index 4768 out of bounds for feature temperature_t-18. Skipping.
# Warning: Index 5331 out of bounds for feature lag_1h_t-1. Skipping.
# Warning: Index 3099 out of bounds for feature rolling_24h_max_t-71. Skipping.
# Warning: Index 1794 out of bounds for feature wind_speed_t-111. Skipping.
# Warning: Index 4155 out of bounds for feature rolling_24h_max_t-38. Skipping.
# Warning: Index 5235 out of bounds for feature lag_1h_t-4. Skipping.
# Warning: Index 2494 out of bounds for feature delta_24h_t-90. Skipping.
# Warning: Index 1976 out of bounds for feature rolling_3h_avg_t-106. Skipping.
# Warning: Index 2995 out of bounds for feature lag_1h_t-74. Skipping.
# Warning: Index 2103 out of bounds for feature lag_168h_t-102. Skipping.
# Warning: Index 5059 out of bounds for feature humidity_t-9. Skipping.
# Warning: Index 4764 out of bounds for feature change_rate_1h_t-19. Skipping.
# Warning: Index 2680 out of bounds for feature rolling_3h_avg_t-84. Skipping.
# Warning: Index 2201 out of bounds for feature rolling_6h_max_t-99. Skipping.
# Warning: Index 1215 out of bounds for feature daily_range_lag_1d_t-130. Skipping.
# Warning: Index 4275 out of bounds for feature lag_1h_t-34. Skipping.
# Warning: Index 4677 out of bounds for feature snow_t-21. Skipping.
# Warning: Index 1062 out of bounds for feature input_t-134. Skipping.
# Warning: Index 1827 out of bounds for feature humidity_t-110. Skipping.
# Warning: Index 823 out of bounds for feature lag_168h_t-142. Skipping.
# Warning: Index 4958 out of bounds for feature delta_24h_t-13. Skipping.
# Warning: Index 182 out of bounds for feature lag_24h_t-162. Skipping.
# Warning: Index 5086 out of bounds for feature delta_24h_t-9. Skipping.
# Warning: Index 1881 out of bounds for feature rolling_6h_max_t-109. Skipping.
# Warning: Index 3608 out of bounds for feature rolling_3h_avg_t-55. Skipping.
# Warning: Index 1562 out of bounds for feature rolling_6h_avg_t-119. Skipping.
# Warning: Index 535 out of bounds for feature lag_168h_t-151. Skipping.
# Warning: Index 4119 out of bounds for feature lag_168h_t-39. Skipping.
# Warning: Index 2935 out of bounds for feature lag_168h_t-76. Skipping.
# Warning: Index 147 out of bounds for feature lag_1h_t-163. Skipping.
# Warning: Index 894 out of bounds for feature delta_24h_t-140. Skipping.
# Warning: Index 1337 out of bounds for feature rolling_6h_max_t-126. Skipping.
# Warning: Index 888 out of bounds for feature rolling_3h_avg_t-140. Skipping.
# Warning: Index 2266 out of bounds for feature rolling_6h_avg_t-97. Skipping.
# Warning: Index 5184 out of bounds for feature temperature_t-5. Skipping.
# Warning: Index 4062 out of bounds for feature delta_24h_t-41. Skipping.
# Warning: Index 3750 out of bounds for feature input_t-50. Skipping.
# Warning: Index 5305 out of bounds for feature rolling_6h_max_t-2. Skipping.
# Warning: Index 87 out of bounds for feature lag_168h_t-165. Skipping.
# Warning: Index 2970 out of bounds for feature rolling_6h_avg_t-75. Skipping.
# Warning: Index 4088 out of bounds for feature rolling_3h_avg_t-40. Skipping.
# Warning: Index 1112 out of bounds for feature rolling_3h_avg_t-133. Skipping.
# Warning: Index 3565 out of bounds for feature week_t-56. Skipping.
# Warning: Index 1248 out of bounds for feature temperature_t-128. Skipping.
# Warning: Index 2328 out of bounds for feature rolling_3h_avg_t-95. Skipping.
# Warning: Index 3449 out of bounds for feature rolling_6h_max_t-60. Skipping.
# Warning: Index 1431 out of bounds for feature lag_168h_t-123. Skipping.
# Warning: Index 3283 out of bounds for feature lag_1h_t-65. Skipping.
# Warning: Index 4126 out of bounds for feature delta_24h_t-39. Skipping.
# Warning: Index 441 out of bounds for feature rolling_6h_max_t-154. Skipping.
# Warning: Index 5115 out of bounds for feature rolling_24h_max_t-8. Skipping.
# Warning: Index 3808 out of bounds for feature temperature_t-48. Skipping.
# Warning: Index 1115 out of bounds for feature rolling_24h_max_t-133. Skipping.
# Warning: Index 3802 out of bounds for feature rolling_6h_avg_t-49. Skipping.
# Warning: Index 2871 out of bounds for feature lag_168h_t-78. Skipping.
# Warning: Index 4358 out of bounds for feature input_t-31. Skipping.
# Warning: Index 3191 out of bounds for feature lag_168h_t-68. Skipping.
# Warning: Index 377 out of bounds for feature rolling_6h_max_t-156. Skipping.
# Warning: Index 3159 out of bounds for feature lag_168h_t-69. Skipping.
# Warning: Index 5222 out of bounds for feature input_t-4. Skipping.
# Warning: Index 604 out of bounds for feature change_rate_1h_t-149. Skipping.
# Warning: Index 5030 out of bounds for feature input_t-10. Skipping.
# Warning: Index 4344 out of bounds for feature rolling_3h_avg_t-32. Skipping.
# Warning: Index 919 out of bounds for feature lag_168h_t-139. Skipping.
# Warning: Index 5241 out of bounds for feature rolling_6h_max_t-4. Skipping.
# Warning: Index 1907 out of bounds for feature lag_1h_t-108. Skipping.
# Warning: Index 2045 out of bounds for feature rolling_7d_std_t-104. Skipping.
# Warning: Index 2554 out of bounds for feature rolling_6h_avg_t-88. Skipping.
# Warning: Index 5281 out of bounds for feature precipitation_t-2. Skipping.
# Warning: Index 572 out of bounds for feature change_rate_1h_t-150. Skipping.
# Warning: Index 5215 out of bounds for feature daily_range_lag_1d_t-5. Skipping.
# Warning: Index 4570 out of bounds for feature rolling_6h_avg_t-25. Skipping.
# Warning: Index 4219 out of bounds for feature rolling_24h_max_t-36. Skipping.
# Warning: Index 4375 out of bounds for feature lag_168h_t-31. Skipping.
# Warning: Index 4407 out of bounds for feature lag_168h_t-30. Skipping.
# Warning: Index 216 out of bounds for feature rolling_3h_avg_t-161. Skipping.
# Warning: Index 390 out of bounds for feature input_t-155. Skipping.
# Warning: Index 5370 out of bounds for feature rolling_6h_avg_t-0. Skipping.
# Warning: Index 1852 out of bounds for feature change_rate_1h_t-110. Skipping.
# Warning: Index 5216 out of bounds for feature temperature_t-4. Skipping.
# Warning: Index 5148 out of bounds for feature change_rate_1h_t-7. Skipping.
# Warning: Index 2430 out of bounds for feature delta_24h_t-92. Skipping.
# Warning: Index 2563 out of bounds for feature humidity_t-87. Skipping.
# Warning: Index 2374 out of bounds for feature input_t-93. Skipping.
# Warning: Index 4158 out of bounds for feature delta_24h_t-38. Skipping.
# Warning: Index 4600 out of bounds for feature rolling_3h_avg_t-24. Skipping.
# Warning: Index 4408 out of bounds for feature rolling_3h_avg_t-30. Skipping.
# Warning: Index 3481 out of bounds for feature rolling_6h_max_t-59. Skipping.
# Warning: Index 4504 out of bounds for feature rolling_3h_avg_t-27. Skipping.
# Warning: Index 3771 out of bounds for feature rolling_24h_max_t-50. Skipping.
# Warning: Index 5210 out of bounds for feature rolling_6h_avg_t-5. Skipping.
# Warning: Index 4098 out of bounds for feature wind_speed_t-39. Skipping.
# Warning: Index 867 out of bounds for feature humidity_t-140. Skipping.
# Warning: Index 1887 out of bounds for feature daily_range_lag_1d_t-109. Skipping.
# Warning: Index 1570 out of bounds for feature wind_speed_t-118. Skipping.
# Warning: Index 4248 out of bounds for feature rolling_3h_avg_t-35. Skipping.
# Warning: Index 499 out of bounds for feature lag_1h_t-152. Skipping.
# Warning: Index 3544 out of bounds for feature rolling_3h_avg_t-57. Skipping.
# Warning: Index 2076 out of bounds for feature change_rate_1h_t-103. Skipping.
# Warning: Index 4179 out of bounds for feature lag_1h_t-37. Skipping.
# Warning: Index 2371 out of bounds for feature humidity_t-93. Skipping.
# Warning: Index 574 out of bounds for feature delta_24h_t-150. Skipping.
# Warning: Index 4572 out of bounds for feature change_rate_1h_t-25. Skipping.
# Warning: Index 1043 out of bounds for feature lag_1h_t-135. Skipping.
# Warning: Index 1474 out of bounds for feature wind_speed_t-121. Skipping.
# Warning: Index 5090 out of bounds for feature wind_speed_t-8. Skipping.
# Warning: Index 796 out of bounds for feature change_rate_1h_t-143. Skipping.
# Warning: Index 5243 out of bounds for feature rolling_24h_max_t-4. Skipping.
# Warning: Index 62 out of bounds for feature delta_24h_t-166. Skipping.
# Warning: Index 5342 out of bounds for feature delta_24h_t-1. Skipping.
# Warning: Index 663 out of bounds for feature lag_168h_t-147. Skipping.
# Warning: Index 1087 out of bounds for feature daily_range_lag_1d_t-134. Skipping.
# Warning: Index 4215 out of bounds for feature lag_168h_t-36. Skipping.
# Warning: Index 33 out of bounds for feature precipitation_t-166. Skipping.
# Warning: Index 1500 out of bounds for feature change_rate_1h_t-121. Skipping.
# Warning: Index 375 out of bounds for feature lag_168h_t-156. Skipping.
# Warning: Index 1476 out of bounds for feature atmospheric_pressure_t-121. Skipping.
# Warning: Index 1798 out of bounds for feature input_t-111. Skipping.
# Warning: Index 5051 out of bounds for feature rolling_24h_max_t-10. Skipping.
# Warning: Index 2943 out of bounds for feature daily_range_lag_1d_t-76. Skipping.
# Warning: Index 4536 out of bounds for feature rolling_3h_avg_t-26. Skipping.
# Warning: Index 1783 out of bounds for feature lag_168h_t-112. Skipping.
# Warning: Index 58 out of bounds for feature rolling_6h_avg_t-166. Skipping.
# Warning: Index 984 out of bounds for feature rolling_3h_avg_t-137. Skipping.
# Warning: Index 1693 out of bounds for feature rolling_7d_std_t-115. Skipping.
# Warning: Index 439 out of bounds for feature lag_168h_t-154. Skipping.
# Warning: Index 4350 out of bounds for feature delta_24h_t-32. Skipping.
# Warning: Index 4794 out of bounds for feature rolling_6h_avg_t-18. Skipping.
# Warning: Index 4934 out of bounds for feature input_t-13. Skipping.
# Warning: Index 1971 out of bounds for feature lag_1h_t-106. Skipping.
# Warning: Index 4798 out of bounds for feature delta_24h_t-18. Skipping.
# Warning: Index 947 out of bounds for feature lag_1h_t-138. Skipping.
# Warning: Index 1761 out of bounds for feature precipitation_t-112. Skipping.
# Warning: Index 3107 out of bounds for feature humidity_t-70. Skipping.
# Warning: Index 1083 out of bounds for feature rolling_24h_max_t-134. Skipping.
# Warning: Index 3610 out of bounds for feature rolling_6h_avg_t-55. Skipping.
# Warning: Index 3383 out of bounds for feature lag_168h_t-62. Skipping.
# Warning: Index 5203 out of bounds for feature lag_1h_t-5. Skipping.
# Warning: Index 3571 out of bounds for feature lag_1h_t-56. Skipping.
# Warning: Index 4769 out of bounds for feature precipitation_t-18. Skipping.
# Warning: Index 2963 out of bounds for feature lag_1h_t-75. Skipping.
# Warning: Index 5018 out of bounds for feature rolling_6h_avg_t-11. Skipping.
# Warning: Index 4610 out of bounds for feature wind_speed_t-23. Skipping.
# Warning: Index 634 out of bounds for feature rolling_6h_avg_t-148. Skipping.
# Warning: Index 3675 out of bounds for feature rolling_24h_max_t-53. Skipping.
# Warning: Index 3356 out of bounds for feature change_rate_1h_t-63. Skipping.
# Warning: Index 1466 out of bounds for feature rolling_6h_avg_t-122. Skipping.
# Warning: Index 4403 out of bounds for feature lag_1h_t-30. Skipping.
# Warning: Index 4503 out of bounds for feature lag_168h_t-27. Skipping.
# Warning: Index 2592 out of bounds for feature temperature_t-86. Skipping.
# Warning: Index 1148 out of bounds for feature change_rate_1h_t-132. Skipping.
# Warning: Index 2916 out of bounds for feature atmospheric_pressure_t-76. Skipping.
# Warning: Index 3354 out of bounds for feature rolling_6h_avg_t-63. Skipping.
# Warning: Index 5310 out of bounds for feature delta_24h_t-2. Skipping.
# Warning: Index 2439 out of bounds for feature dayofmonth_t-91. Skipping.
# Warning: Index 5022 out of bounds for feature delta_24h_t-11. Skipping.
# Warning: Index 1791 out of bounds for feature daily_range_lag_1d_t-112. Skipping.
# Warning: Index 2969 out of bounds for feature rolling_6h_max_t-75. Skipping.
# Warning: Index 2367 out of bounds for feature daily_range_lag_1d_t-94. Skipping.
# Warning: Index 4691 out of bounds for feature lag_1h_t-21. Skipping.
# Warning: Index 2694 out of bounds for feature input_t-83. Skipping.
# Warning: Index 1945 out of bounds for feature rolling_6h_max_t-107. Skipping.
# Warning: Index 4247 out of bounds for feature lag_168h_t-35. Skipping.
# Warning: Index 575 out of bounds for feature daily_range_lag_1d_t-150. Skipping.
# Warning: Index 1820 out of bounds for feature change_rate_1h_t-111. Skipping.
# Warning: Index 1977 out of bounds for feature rolling_6h_max_t-106. Skipping.
# Warning: Index 3586 out of bounds for feature wind_speed_t-55. Skipping.
# Warning: Index 2298 out of bounds for feature rolling_6h_avg_t-96. Skipping.
# Warning: Index 1254 out of bounds for feature input_t-128. Skipping.
# Warning: Index 4250 out of bounds for feature rolling_6h_avg_t-35. Skipping.
# Warning: Index 161 out of bounds for feature precipitation_t-162. Skipping.
# Warning: Index 3475 out of bounds for feature lag_1h_t-59. Skipping.
# Warning: Index 4355 out of bounds for feature humidity_t-31. Skipping.
# Warning: Index 3902 out of bounds for feature delta_24h_t-46. Skipping.
# Warning: Index 4702 out of bounds for feature delta_24h_t-21. Skipping.
# Warning: Index 3324 out of bounds for feature change_rate_1h_t-64. Skipping.
# Warning: Index 1403 out of bounds for feature rolling_24h_max_t-124. Skipping.
# Warning: Index 4343 out of bounds for feature lag_168h_t-32. Skipping.
# Warning: Index 3714 out of bounds for feature wind_speed_t-51. Skipping.
# Warning: Index 1760 out of bounds for feature temperature_t-112. Skipping.
# Warning: Index 4222 out of bounds for feature delta_24h_t-36. Skipping.
# Warning: Index 1052 out of bounds for feature change_rate_1h_t-135. Skipping.
# Warning: Index 4135 out of bounds for feature dayofmonth_t-38. Skipping.
# Warning: Index 3491 out of bounds for feature humidity_t-58. Skipping.
# Warning: Index 3038 out of bounds for feature delta_24h_t-73. Skipping.
# Warning: Index 546 out of bounds for feature wind_speed_t-150. Skipping.
# Warning: Index 4379 out of bounds for feature rolling_24h_max_t-31. Skipping.
# Warning: Index 542 out of bounds for feature delta_24h_t-151. Skipping.
# Warning: Index 1395 out of bounds for feature lag_1h_t-124. Skipping.
# Warning: Index 478 out of bounds for feature delta_24h_t-153. Skipping.
# Warning: Index 3390 out of bounds for feature delta_24h_t-62. Skipping.
# Warning: Index 1662 out of bounds for feature delta_24h_t-116. Skipping.
# Warning: Index 1416 out of bounds for feature dayofweek_t-123. Skipping.
# Warning: Index 3740 out of bounds for feature change_rate_1h_t-51. Skipping.
# Warning: Index 2588 out of bounds for feature change_rate_1h_t-87. Skipping.
# Warning: Index 2950 out of bounds for feature input_t-75. Skipping.
# Warning: Index 5276 out of bounds for feature change_rate_1h_t-3. Skipping.
# Warning: Index 1523 out of bounds for feature lag_1h_t-120. Skipping.
# Warning: Index 5223 out of bounds for feature dayofmonth_t-4. Skipping.
# Warning: Index 5246 out of bounds for feature delta_24h_t-4. Skipping.
# Warning: Index 4535 out of bounds for feature lag_168h_t-26. Skipping.
# Warning: Index 3386 out of bounds for feature rolling_6h_avg_t-62. Skipping.
# Warning: Index 2850 out of bounds for feature wind_speed_t-78. Skipping.
# Warning: Index 4390 out of bounds for feature input_t-30. Skipping.
# Warning: Index 4198 out of bounds for feature input_t-36. Skipping.
# Warning: Index 4435 out of bounds for feature lag_1h_t-29. Skipping.
# Warning: Index 3895 out of bounds for feature lag_168h_t-46. Skipping.
# Warning: Index 4960 out of bounds for feature temperature_t-12. Skipping.
# Warning: Index 1502 out of bounds for feature delta_24h_t-121. Skipping.
# Warning: Index 2912 out of bounds for feature temperature_t-76. Skipping.
# Warning: Index 192 out of bounds for feature temperature_t-161. Skipping.
# Warning: Index 1636 out of bounds for feature atmospheric_pressure_t-116. Skipping.
# Warning: Index 3667 out of bounds for feature lag_1h_t-53. Skipping.
# Warning: Index 3867 out of bounds for feature rolling_24h_max_t-47. Skipping.
# Warning: Index 2819 out of bounds for feature humidity_t-79. Skipping.
# Warning: Index 4122 out of bounds for feature rolling_6h_avg_t-39. Skipping.
# Warning: Index 5250 out of bounds for feature wind_speed_t-3. Skipping.
# Warning: Index 922 out of bounds for feature rolling_6h_avg_t-139. Skipping.
# Warning: Index 4486 out of bounds for feature input_t-27. Skipping.
# Warning: Index 636 out of bounds for feature change_rate_1h_t-148. Skipping.
# Warning: Index 4284 out of bounds for feature change_rate_1h_t-34. Skipping.
# Warning: Index 839 out of bounds for feature dayofmonth_t-141. Skipping.
# Warning: Index 570 out of bounds for feature rolling_6h_avg_t-150. Skipping.
# Warning: Index 4797 out of bounds for feature rolling_7d_std_t-18. Skipping.
# Warning: Index 1561 out of bounds for feature rolling_6h_max_t-119. Skipping.
# Warning: Index 4772 out of bounds for feature atmospheric_pressure_t-18. Skipping.
# Warning: Index 4802 out of bounds for feature wind_speed_t-17. Skipping.
# Warning: Index 2711 out of bounds for feature lag_168h_t-83. Skipping.
# Warning: Index 3448 out of bounds for feature rolling_3h_avg_t-60. Skipping.
# Warning: Index 611 out of bounds for feature humidity_t-148. Skipping.
# Warning: Index 1506 out of bounds for feature wind_speed_t-120. Skipping.
# Warning: Index 4548 out of bounds for feature atmospheric_pressure_t-25. Skipping.
# Warning: Index 4567 out of bounds for feature lag_168h_t-25. Skipping.
# Warning: Index 1084 out of bounds for feature change_rate_1h_t-134. Skipping.
# Warning: Index 3238 out of bounds for feature input_t-66. Skipping.
# Warning: Index 3800 out of bounds for feature rolling_3h_avg_t-49. Skipping.
# Warning: Index 4183 out of bounds for feature lag_168h_t-37. Skipping.
# Warning: Index 4094 out of bounds for feature delta_24h_t-40. Skipping.
# Warning: Index 1158 out of bounds for feature input_t-131. Skipping.
# Warning: Index 2227 out of bounds for feature lag_1h_t-98. Skipping.
# Warning: Index 3731 out of bounds for feature lag_1h_t-51. Skipping.
# Warning: Index 1220 out of bounds for feature atmospheric_pressure_t-129. Skipping.
# Warning: Index 1730 out of bounds for feature wind_speed_t-113. Skipping.
# Warning: Index 4860 out of bounds for feature change_rate_1h_t-16. Skipping.
# Warning: Index 2336 out of bounds for feature temperature_t-94. Skipping.
# Warning: Index 1400 out of bounds for feature rolling_3h_avg_t-124. Skipping.
# Warning: Index 4984 out of bounds for feature rolling_3h_avg_t-12. Skipping.
# Warning: Index 1310 out of bounds for feature delta_24h_t-127. Skipping.
# Warning: Index 801 out of bounds for feature precipitation_t-142. Skipping.
# Warning: Index 606 out of bounds for feature delta_24h_t-149. Skipping.
# Warning: Index 4162 out of bounds for feature wind_speed_t-37. Skipping.
# Warning: Index 2872 out of bounds for feature rolling_3h_avg_t-78. Skipping.
# Warning: Index 2713 out of bounds for feature rolling_6h_max_t-83. Skipping.
# Warning: Index 3411 out of bounds for feature lag_1h_t-61. Skipping.
# Warning: Index 1758 out of bounds for feature delta_24h_t-113. Skipping.
# Warning: Index 638 out of bounds for feature delta_24h_t-148. Skipping.
# Warning: Index 3804 out of bounds for feature change_rate_1h_t-49. Skipping.
# Warning: Index 4762 out of bounds for feature rolling_6h_avg_t-19. Skipping.
# Warning: Index 4926 out of bounds for feature delta_24h_t-14. Skipping.
# Warning: Index 4476 out of bounds for feature change_rate_1h_t-28. Skipping.
# Warning: Index 5048 out of bounds for feature rolling_3h_avg_t-10. Skipping.
# Warning: Index 610 out of bounds for feature wind_speed_t-148. Skipping.
# Warning: Index 3806 out of bounds for feature delta_24h_t-49. Skipping.
# Warning: Index 2936 out of bounds for feature rolling_3h_avg_t-76. Skipping.
# Warning: Index 223 out of bounds for feature daily_range_lag_1d_t-161. Skipping.
# Warning: Index 2874 out of bounds for feature rolling_6h_avg_t-78. Skipping.
# Warning: Index 2867 out of bounds for feature lag_1h_t-78. Skipping.
# Warning: Index 1049 out of bounds for feature rolling_6h_max_t-135. Skipping.
# Warning: Index 5339 out of bounds for feature rolling_24h_max_t-1. Skipping.
# Warning: Index 3743 out of bounds for feature daily_range_lag_1d_t-51. Skipping.
# Warning: Index 4478 out of bounds for feature delta_24h_t-28. Skipping.
# Warning: Index 1982 out of bounds for feature delta_24h_t-106. Skipping.
# Warning: Index 4231 out of bounds for feature dayofmonth_t-35. Skipping.
# Warning: Index 3966 out of bounds for feature delta_24h_t-44. Skipping.
# Warning: Index 889 out of bounds for feature rolling_6h_max_t-140. Skipping.
# Warning: Index 5016 out of bounds for feature rolling_3h_avg_t-11. Skipping.
# Warning: Index 1111 out of bounds for feature lag_168h_t-133. Skipping.
# Warning: Index 2136 out of bounds for feature rolling_3h_avg_t-101. Skipping.
# Warning: Index 2236 out of bounds for feature change_rate_1h_t-98. Skipping.
# Warning: Index 2272 out of bounds for feature temperature_t-96. Skipping.
# Warning: Index 5050 out of bounds for feature rolling_6h_avg_t-10. Skipping.
# Warning: Index 376 out of bounds for feature rolling_3h_avg_t-156. Skipping.
# Warning: Index 3703 out of bounds for feature lag_168h_t-52. Skipping.
# Warning: Index 471 out of bounds for feature lag_168h_t-153. Skipping.
# Warning: Index 833 out of bounds for feature precipitation_t-141. Skipping.
# Warning: Index 892 out of bounds for feature change_rate_1h_t-140. Skipping.
# Warning: Index 1307 out of bounds for feature rolling_24h_max_t-127. Skipping.
# Warning: Index 2914 out of bounds for feature wind_speed_t-76. Skipping.
# Warning: Index 5282 out of bounds for feature wind_speed_t-2. Skipping.
# Warning: Index 2654 out of bounds for feature delta_24h_t-85. Skipping.
# Warning: Index 1724 out of bounds for feature change_rate_1h_t-114. Skipping.
# Warning: Index 3255 out of bounds for feature lag_168h_t-66. Skipping.
# Warning: Index 1943 out of bounds for feature lag_168h_t-107. Skipping.
# Warning: Index 1667 out of bounds for feature humidity_t-115. Skipping.
# Warning: Index 470 out of bounds for feature lag_24h_t-153. Skipping.
# Warning: Index 2628 out of bounds for feature atmospheric_pressure_t-85. Skipping.
# Warning: Index 1629 out of bounds for feature rolling_7d_std_t-117. Skipping.
# Warning: Index 615 out of bounds for feature dayofmonth_t-148. Skipping.
# Warning: Index 1756 out of bounds for feature change_rate_1h_t-113. Skipping.
# Warning: Index 2758 out of bounds for feature input_t-81. Skipping.
# Warning: Index 3612 out of bounds for feature change_rate_1h_t-55. Skipping.
# Warning: Index 1923 out of bounds for feature humidity_t-107. Skipping.
# Warning: Index 4191 out of bounds for feature daily_range_lag_1d_t-37. Skipping.
# Warning: Index 2611 out of bounds for feature lag_1h_t-86. Skipping.
# Warning: Index 1342 out of bounds for feature delta_24h_t-126. Skipping.
# Warning: Index 4990 out of bounds for feature delta_24h_t-12. Skipping.
# Warning: Index 1378 out of bounds for feature wind_speed_t-124. Skipping.
# Warning: Index 3929 out of bounds for feature rolling_6h_max_t-45. Skipping.
# Warning: Index 2590 out of bounds for feature delta_24h_t-87. Skipping.
# Warning: Index 1335 out of bounds for feature lag_168h_t-126. Skipping.
# Warning: Index 4083 out of bounds for feature lag_1h_t-40. Skipping.
# Warning: Index 3002 out of bounds for feature rolling_6h_avg_t-74. Skipping.
# Warning: Index 1465 out of bounds for feature rolling_6h_max_t-122. Skipping.
# Warning: Index 5094 out of bounds for feature input_t-8. Skipping.
# Warning: Index 4282 out of bounds for feature rolling_6h_avg_t-34. Skipping.
# Warning: Index 310 out of bounds for feature lag_24h_t-158. Skipping.
# Warning: Index 1250 out of bounds for feature wind_speed_t-128. Skipping.
# Warning: Index 579 out of bounds for feature humidity_t-149. Skipping.
# Warning: Index 2879 out of bounds for feature daily_range_lag_1d_t-78. Skipping.
# Warning: Index 4243 out of bounds for feature lag_1h_t-35. Skipping.
# Warning: Index 254 out of bounds for feature delta_24h_t-160. Skipping.
# Warning: Index 3251 out of bounds for feature lag_1h_t-66. Skipping.
# Warning: Index 514 out of bounds for feature wind_speed_t-151. Skipping.
# Warning: Index 247 out of bounds for feature lag_168h_t-160. Skipping.
# Warning: Index 2402 out of bounds for feature wind_speed_t-92. Skipping.
# Warning: Index 126 out of bounds for feature delta_24h_t-164. Skipping.
# Warning: Index 1859 out of bounds for feature humidity_t-109. Skipping.
# Warning: Index 2429 out of bounds for feature rolling_7d_std_t-92. Skipping.
# Warning: Index 662 out of bounds for feature lag_24h_t-147. Skipping.
# Warning: Index 4674 out of bounds for feature wind_speed_t-21. Skipping.
# Warning: Index 1950 out of bounds for feature delta_24h_t-107. Skipping.
# Warning: Index 4604 out of bounds for feature change_rate_1h_t-24. Skipping.
# Warning: Index 2722 out of bounds for feature wind_speed_t-82. Skipping.
# Warning: Index 4830 out of bounds for feature delta_24h_t-17. Skipping.
# Warning: Index 3460 out of bounds for feature atmospheric_pressure_t-59. Skipping.
# Warning: Index 95 out of bounds for feature daily_range_lag_1d_t-165. Skipping.
# Warning: Index 2042 out of bounds for feature rolling_6h_avg_t-104. Skipping.
# Warning: Index 1438 out of bounds for feature delta_24h_t-123. Skipping.
# Warning: Index 222 out of bounds for feature delta_24h_t-161. Skipping.
# Warning: Index 1091 out of bounds for feature humidity_t-133. Skipping.
# Warning: Index 4889 out of bounds for feature rolling_6h_max_t-15. Skipping.
# Warning: Index 4442 out of bounds for feature rolling_6h_avg_t-29. Skipping.
# Warning: Index 2918 out of bounds for feature input_t-76. Skipping.
# Warning: Index 2332 out of bounds for feature change_rate_1h_t-95. Skipping.
# Warning: Index 1587 out of bounds for feature lag_1h_t-118. Skipping.
# Warning: Index 3225 out of bounds for feature rolling_6h_max_t-67. Skipping.
# Warning: Index 348 out of bounds for feature change_rate_1h_t-157. Skipping.
# Warning: Index 5346 out of bounds for feature wind_speed_t-0. Skipping.
# Warning: Index 4771 out of bounds for feature humidity_t-18. Skipping.
# Warning: Index 3262 out of bounds for feature delta_24h_t-66. Skipping.
# Warning: Index 5219 out of bounds for feature humidity_t-4. Skipping.
# Warning: Index 5084 out of bounds for feature change_rate_1h_t-9. Skipping.
# Warning: Index 2907 out of bounds for feature rolling_24h_max_t-77. Skipping.
# Warning: Index 3575 out of bounds for feature lag_168h_t-56. Skipping.
# Warning: Index 2118 out of bounds for feature input_t-101. Skipping.
# Warning: Index 4472 out of bounds for feature rolling_3h_avg_t-28. Skipping.
# Warning: Index 2044 out of bounds for feature change_rate_1h_t-104. Skipping.
# Warning: Index 2771 out of bounds for feature lag_1h_t-81. Skipping.
# Warning: Index 2775 out of bounds for feature lag_168h_t-81. Skipping.
# Warning: Index 3321 out of bounds for feature rolling_6h_max_t-64. Skipping.
# Warning: Index 2012 out of bounds for feature change_rate_1h_t-105. Skipping.
# Warning: Index 4540 out of bounds for feature change_rate_1h_t-26. Skipping.
# Warning: Index 860 out of bounds for feature change_rate_1h_t-141. Skipping.
# Warning: Index 2619 out of bounds for feature rolling_24h_max_t-86. Skipping.
# Warning: Index 1180 out of bounds for feature change_rate_1h_t-131. Skipping.
# Warning: Index 509 out of bounds for feature rolling_7d_std_t-152. Skipping.
# Warning: Index 1050 out of bounds for feature rolling_6h_avg_t-135. Skipping.
# Warning: Index 2111 out of bounds for feature daily_range_lag_1d_t-102. Skipping.
# Warning: Index 4188 out of bounds for feature change_rate_1h_t-37. Skipping.
# Warning: Index 2335 out of bounds for feature daily_range_lag_1d_t-95. Skipping.
# Warning: Index 1376 out of bounds for feature temperature_t-124. Skipping.
# Warning: Index 2302 out of bounds for feature delta_24h_t-96. Skipping.
# Warning: Index 252 out of bounds for feature change_rate_1h_t-160. Skipping.
# Warning: Index 1082 out of bounds for feature rolling_6h_avg_t-134. Skipping.
# Warning: Index 4636 out of bounds for feature change_rate_1h_t-23. Skipping.
# Warning: Index 862 out of bounds for feature delta_24h_t-141. Skipping.
# Warning: Index 951 out of bounds for feature lag_168h_t-138. Skipping.
# Warning: Index 1305 out of bounds for feature rolling_6h_max_t-127. Skipping.
# Warning: Index 1980 out of bounds for feature change_rate_1h_t-106. Skipping.
# Warning: Index 2587 out of bounds for feature rolling_24h_max_t-87. Skipping.
# Warning: Index 2150 out of bounds for feature input_t-100. Skipping.
# Warning: Index 2108 out of bounds for feature change_rate_1h_t-102. Skipping.
# Warning: Index 3097 out of bounds for feature rolling_6h_max_t-71. Skipping.
# Warning: Index 2739 out of bounds for feature lag_1h_t-82. Skipping.
# Warning: Index 568 out of bounds for feature rolling_3h_avg_t-150. Skipping.
# Warning: Index 3515 out of bounds for feature rolling_24h_max_t-58. Skipping.
# Warning: Index 3611 out of bounds for feature rolling_24h_max_t-55. Skipping.
# Warning: Index 3235 out of bounds for feature humidity_t-66. Skipping.
# Warning: Index 3768 out of bounds for feature rolling_3h_avg_t-50. Skipping.
# Warning: Index 828 out of bounds for feature change_rate_1h_t-142. Skipping.
# Warning: Index 2391 out of bounds for feature lag_168h_t-93. Skipping.
# Warning: Index 787 out of bounds for feature lag_1h_t-143. Skipping.
# Warning: Index 3106 out of bounds for feature wind_speed_t-70. Skipping.
# Warning: Index 582 out of bounds for feature input_t-149. Skipping.
# Warning: Index 2623 out of bounds for feature daily_range_lag_1d_t-86. Skipping.
# Warning: Index 646 out of bounds for feature input_t-147. Skipping.
# Warning: Index 156 out of bounds for feature change_rate_1h_t-163. Skipping.
# Warning: Index 4216 out of bounds for feature rolling_3h_avg_t-36. Skipping.
# Warning: Index 2054 out of bounds for feature input_t-103. Skipping.
# Warning: Index 4055 out of bounds for feature lag_168h_t-41. Skipping.
# Warning: Index 3196 out of bounds for feature change_rate_1h_t-68. Skipping.
# Warning: Index 486 out of bounds for feature input_t-152. Skipping.
# Warning: Index 5182 out of bounds for feature delta_24h_t-6. Skipping.
# Warning: Index 915 out of bounds for feature lag_1h_t-139. Skipping.
# Warning: Index 791 out of bounds for feature lag_168h_t-143. Skipping.
# Warning: Index 4259 out of bounds for feature humidity_t-34. Skipping.
# Warning: Index 1207 out of bounds for feature lag_168h_t-130. Skipping.
# Warning: Index 2172 out of bounds for feature change_rate_1h_t-100. Skipping.
# Warning: Index 4755 out of bounds for feature lag_1h_t-19. Skipping.
# Warning: Index 979 out of bounds for feature lag_1h_t-137. Skipping.
# Warning: Index 1882 out of bounds for feature rolling_6h_avg_t-109. Skipping.
# Warning: Index 4606 out of bounds for feature delta_24h_t-24. Skipping.
# Warning: Index 2268 out of bounds for feature change_rate_1h_t-97. Skipping.
# Warning: Index 578 out of bounds for feature wind_speed_t-149. Skipping.
# Warning: Index 5347 out of bounds for feature humidity_t-0. Skipping.
# Warning: Index 3394 out of bounds for feature wind_speed_t-61. Skipping.
# Warning: Index 2520 out of bounds for feature rolling_3h_avg_t-89. Skipping.
# Warning: Index 627 out of bounds for feature lag_1h_t-148. Skipping.
# Warning: Index 3959 out of bounds for feature lag_168h_t-44. Skipping.
# Warning: Index 5244 out of bounds for feature change_rate_1h_t-4. Skipping.
# Warning: Index 4482 out of bounds for feature wind_speed_t-27. Skipping.
# Warning: Index 410 out of bounds for feature rolling_6h_avg_t-155. Skipping.
# Warning: Index 2662 out of bounds for feature input_t-84. Skipping.
# Warning: Index 2684 out of bounds for feature change_rate_1h_t-84. Skipping.
# Warning: Index 3224 out of bounds for feature rolling_3h_avg_t-67. Skipping.
# Warning: Index 1282 out of bounds for feature wind_speed_t-127. Skipping.
# Warning: Index 1146 out of bounds for feature rolling_6h_avg_t-132. Skipping.
# Warning: Index 1670 out of bounds for feature input_t-115. Skipping.
# Warning: Index 3580 out of bounds for feature change_rate_1h_t-56. Skipping.
# Warning: Index 4796 out of bounds for feature change_rate_1h_t-18. Skipping.
# Warning: Index 2975 out of bounds for feature daily_range_lag_1d_t-75. Skipping.
# Warning: Index 2483 out of bounds for feature lag_1h_t-90. Skipping.
# Warning: Index 3455 out of bounds for feature daily_range_lag_1d_t-60. Skipping.
# Warning: Index 2876 out of bounds for feature change_rate_1h_t-78. Skipping.
# Warning: Index 344 out of bounds for feature rolling_3h_avg_t-157. Skipping.
# Warning: Index 444 out of bounds for feature change_rate_1h_t-154. Skipping.
# Warning: Index 4413 out of bounds for feature rolling_7d_std_t-30. Skipping.
# Warning: Index 2399 out of bounds for feature daily_range_lag_1d_t-93. Skipping.
# Warning: Index 2534 out of bounds for feature input_t-88. Skipping.
# Warning: Index 4931 out of bounds for feature humidity_t-13. Skipping.
# Warning: Index 4450 out of bounds for feature wind_speed_t-28. Skipping.
# Warning: Index 3935 out of bounds for feature daily_range_lag_1d_t-45. Skipping.
# Warning: Index 4412 out of bounds for feature change_rate_1h_t-30. Skipping.
# Warning: Index 1246 out of bounds for feature delta_24h_t-129. Skipping.
# Warning: Index 956 out of bounds for feature change_rate_1h_t-138. Skipping.
# Warning: Index 5371 out of bounds for feature rolling_24h_max_t-0. Skipping.
# Warning: Index 4870 out of bounds for feature input_t-15. Skipping.
# Warning: Index 670 out of bounds for feature delta_24h_t-147. Skipping.
# Warning: Index 283 out of bounds for feature rolling_24h_max_t-159. Skipping.
# Warning: Index 5187 out of bounds for feature humidity_t-5. Skipping.
# Warning: Index 548 out of bounds for feature atmospheric_pressure_t-150. Skipping.
# Warning: Index 567 out of bounds for feature lag_168h_t-150. Skipping.
# Warning: Index 4582 out of bounds for feature input_t-24. Skipping.
# Warning: Index 279 out of bounds for feature lag_168h_t-159. Skipping.
# Warning: Index 2586 out of bounds for feature rolling_6h_avg_t-87. Skipping.
# Warning: Index 2782 out of bounds for feature delta_24h_t-81. Skipping.
# Warning: Index 3032 out of bounds for feature rolling_3h_avg_t-73. Skipping.
# Warning: Index 2142 out of bounds for feature delta_24h_t-101. Skipping.
# Warning: Index 3842 out of bounds for feature wind_speed_t-47. Skipping.
# Warning: Index 1368 out of bounds for feature rolling_3h_avg_t-125. Skipping.
# Warning: Index 2338 out of bounds for feature wind_speed_t-94. Skipping.
# Warning: Index 599 out of bounds for feature lag_168h_t-149. Skipping.
# Warning: Index 3270 out of bounds for feature input_t-65. Skipping.
# Warning: Index 4642 out of bounds for feature wind_speed_t-22. Skipping.
# Warning: Index 55 out of bounds for feature lag_168h_t-166. Skipping.
# Warning: Index 1350 out of bounds for feature input_t-125. Skipping.
# Warning: Index 1734 out of bounds for feature input_t-113. Skipping.
# Warning: Index 4667 out of bounds for feature rolling_24h_max_t-22. Skipping.
# Warning: Index 2470 out of bounds for feature input_t-90. Skipping.
# Warning: Index 2427 out of bounds for feature rolling_24h_max_t-92. Skipping.
# Warning: Index 1721 out of bounds for feature rolling_6h_max_t-114. Skipping.
# Warning: Index 1510 out of bounds for feature input_t-120. Skipping.
# Warning: Index 760 out of bounds for feature rolling_3h_avg_t-144. Skipping.
# Warning: Index 1059 out of bounds for feature humidity_t-134. Skipping.
# Warning: Index 2776 out of bounds for feature rolling_3h_avg_t-81. Skipping.
# Warning: Index 5212 out of bounds for feature change_rate_1h_t-5. Skipping.
# Warning: Index 4508 out of bounds for feature change_rate_1h_t-27. Skipping.
# Warning: Index 2179 out of bounds for feature humidity_t-99. Skipping.
# Warning: Index 3516 out of bounds for feature change_rate_1h_t-58. Skipping.
# Warning: Index 2167 out of bounds for feature lag_168h_t-100. Skipping.
# Warning: Index 1530 out of bounds for feature rolling_6h_avg_t-120. Skipping.
# Warning: Index 926 out of bounds for feature delta_24h_t-139. Skipping.
# Warning: Index 3780 out of bounds for feature atmospheric_pressure_t-49. Skipping.
# Warning: Index 2387 out of bounds for feature lag_1h_t-93. Skipping.
# Warning: Index 4184 out of bounds for feature rolling_3h_avg_t-37. Skipping.
# Warning: Index 4883 out of bounds for feature lag_1h_t-15. Skipping.
# Warning: Index 838 out of bounds for feature input_t-141. Skipping.
# ...
# Warning: Index 93 out of bounds for feature rolling_7d_std_t-165. Skipping.
# Warning: Index 3031 out of bounds for feature lag_168h_t-73. Skipping.
# Warning: Index 2173 out of bounds for feature rolling_7d_std_t-100. Skipping.
# Warning: Index 544 out of bounds for feature temperature_t-150. Skipping.
# Warning: Index 3351 out of bounds for feature lag_168h_t-63. Skipping.
# Warning: Index 4151 out of bounds for feature lag_168h_t-38. Skipping.
# Warning: Index 2327 out of bounds for feature lag_168h_t-95. Skipping.
# Warning: Index 1152 out of bounds for feature temperature_t-131. Skipping.
# Warning: Index 858 out of bounds for feature rolling_6h_avg_t-141. Skipping.
# Warning: Index 3331 out of bounds for feature humidity_t-63. Skipping.
# Warning: Index 2146 out of bounds for feature wind_speed_t-100. Skipping.
# Warning: Index 1367 out of bounds for feature lag_168h_t-125. Skipping.
# Warning: Index 4220 out of bounds for feature change_rate_1h_t-36. Skipping.
# Warning: Index 3364 out of bounds for feature atmospheric_pressure_t-62. Skipping.
# Warning: Index 3479 out of bounds for feature lag_168h_t-59. Skipping.
# Warning: Index 4574 out of bounds for feature delta_24h_t-25. Skipping.
# Warning: Index 764 out of bounds for feature change_rate_1h_t-144. Skipping.
# Warning: Index 3930 out of bounds for feature rolling_6h_avg_t-45. Skipping.
# Warning: Index 883 out of bounds for feature lag_1h_t-140. Skipping.
# Warning: Index 2291 out of bounds for feature lag_1h_t-96. Skipping.
# Warning: Index 731 out of bounds for feature rolling_24h_max_t-145. Skipping.
# Warning: Index 1975 out of bounds for feature lag_168h_t-106. Skipping.
# Warning: Index 1239 out of bounds for feature lag_168h_t-129. Skipping.
# Warning: Index 1762 out of bounds for feature wind_speed_t-112. Skipping.
# Warning: Index 5150 out of bounds for feature delta_24h_t-7. Skipping.
# Warning: Index 3962 out of bounds for feature rolling_6h_avg_t-44. Skipping.
# Warning: Index 1253 out of bounds for feature snow_t-128. Skipping.
# Warning: Index 2393 out of bounds for feature rolling_6h_max_t-93. Skipping.
# Warning: Index 1363 out of bounds for feature lag_1h_t-125. Skipping.
# Warning: Index 3078 out of bounds for feature input_t-71. Skipping.
# Warning: Index 3878 out of bounds for feature input_t-46. Skipping.
# Warning: Index 4471 out of bounds for feature lag_168h_t-28. Skipping.
# Warning: Index 5146 out of bounds for feature rolling_6h_avg_t-7. Skipping.
# Warning: Index 4643 out of bounds for feature humidity_t-22. Skipping.
# Warning: Index 2137 out of bounds for feature rolling_6h_max_t-101. Skipping.
# Warning: Index 290 out of bounds for feature wind_speed_t-158. Skipping.
# Warning: Index 1436 out of bounds for feature change_rate_1h_t-123. Skipping.
# Warning: Index 1694 out of bounds for feature delta_24h_t-115. Skipping.
# Warning: Index 1759 out of bounds for feature daily_range_lag_1d_t-113. Skipping.
# Warning: Index 902 out of bounds for feature input_t-139. Skipping.
# Warning: Index 5272 out of bounds for feature rolling_3h_avg_t-3. Skipping.
# Warning: Index 134 out of bounds for feature input_t-163. Skipping.
# Warning: Index 4307 out of bounds for feature lag_1h_t-33. Skipping.
# Warning: Index 2910 out of bounds for feature delta_24h_t-77. Skipping.
# Warning: Index 1491 out of bounds for feature lag_1h_t-121. Skipping.
# Warning: Index 3234 out of bounds for feature wind_speed_t-66. Skipping.
# Warning: Index 1247 out of bounds for feature daily_range_lag_1d_t-129. Skipping.
# Warning: Index 153 out of bounds for feature rolling_6h_max_t-163. Skipping.
# Warning: Index 3590 out of bounds for feature input_t-55. Skipping.
# Warning: Index 5190 out of bounds for feature input_t-5. Skipping.
# Warning: Index 4386 out of bounds for feature wind_speed_t-30. Skipping.
# Warning: Index 435 out of bounds for feature lag_1h_t-154. Skipping.
# Warning: Index 3927 out of bounds for feature lag_168h_t-45. Skipping.
# Warning: Index 538 out of bounds for feature rolling_6h_avg_t-151. Skipping.
# Warning: Index 5338 out of bounds for feature rolling_6h_avg_t-1. Skipping.
# Warning: Index 4419 out of bounds for feature humidity_t-29. Skipping.
# Warning: Index 3640 out of bounds for feature rolling_3h_avg_t-54. Skipping.
# Warning: Index 2303 out of bounds for feature daily_range_lag_1d_t-96. Skipping.
# Warning: Index 3970 out of bounds for feature wind_speed_t-43. Skipping.
# Warning: Index 632 out of bounds for feature rolling_3h_avg_t-148. Skipping.
# Warning: Index 3294 out of bounds for feature delta_24h_t-65. Skipping.
# Warning: Index 3319 out of bounds for feature lag_168h_t-64. Skipping.
# Warning: Index 1090 out of bounds for feature wind_speed_t-133. Skipping.
# Warning: Index 1858 out of bounds for feature wind_speed_t-109. Skipping.
# Warning: Index 637 out of bounds for feature rolling_7d_std_t-148. Skipping.
# Warning: Index 1154 out of bounds for feature wind_speed_t-131. Skipping.
# Warning: Index 2946 out of bounds for feature wind_speed_t-75. Skipping.
# Warning: Index 614 out of bounds for feature input_t-148. Skipping.
# Warning: Index 3939 out of bounds for feature humidity_t-44. Skipping.
# Warning: Index 612 out of bounds for feature atmospheric_pressure_t-148. Skipping.
# Warning: Index 4538 out of bounds for feature rolling_6h_avg_t-26. Skipping.
# Warning: Index 680 out of bounds for feature dayofweek_t-146. Skipping.
# Warning: Index 3639 out of bounds for feature lag_168h_t-54. Skipping.
# Warning: Index 1410 out of bounds for feature wind_speed_t-123. Skipping.
# Warning: Index 1171 out of bounds for feature lag_1h_t-131. Skipping.
# Warning: Index 118 out of bounds for feature lag_24h_t-164. Skipping.
# Warning: Index 3036 out of bounds for feature change_rate_1h_t-73. Skipping.
# Warning: Index 446 out of bounds for feature delta_24h_t-154. Skipping.
# Warning: Index 1529 out of bounds for feature rolling_6h_max_t-120. Skipping.
# Warning: Index 3811 out of bounds for feature humidity_t-48. Skipping.
# Warning: Index 563 out of bounds for feature lag_1h_t-150. Skipping.
# Warning: Index 1114 out of bounds for feature rolling_6h_avg_t-133. Skipping.
# Warning: Index 4539 out of bounds for feature rolling_24h_max_t-26. Skipping.
# Warning: Index 728 out of bounds for feature rolling_3h_avg_t-145. Skipping.
# Warning: Index 3801 out of bounds for feature rolling_6h_max_t-49. Skipping.
# Warning: Index 1660 out of bounds for feature change_rate_1h_t-116. Skipping.
# Warning: Index 3198 out of bounds for feature delta_24h_t-68. Skipping.
# Warning: Index 3257 out of bounds for feature rolling_6h_max_t-66. Skipping.
# Warning: Index 34 out of bounds for feature wind_speed_t-166. Skipping.
# Warning: Index 4673 out of bounds for feature precipitation_t-21. Skipping.
# Warning: Index 3961 out of bounds for feature rolling_6h_max_t-44. Skipping.
# Warning: Index 4441 out of bounds for feature rolling_6h_max_t-29. Skipping.
# Warning: Index 802 out of bounds for feature wind_speed_t-142. Skipping.
# Warning: Index 3549 out of bounds for feature rolling_7d_std_t-57. Skipping.
# Warning: Index 412 out of bounds for feature change_rate_1h_t-155. Skipping.
# Warning: Index 4156 out of bounds for feature change_rate_1h_t-38. Skipping.
# Warning: Index 3647 out of bounds for feature daily_range_lag_1d_t-54. Skipping.
# Warning: Index 2078 out of bounds for feature delta_24h_t-103. Skipping.
# Warning: Index 3683 out of bounds for feature humidity_t-52. Skipping.
# Warning: Index 2724 out of bounds for feature atmospheric_pressure_t-82. Skipping.
# Warning: Index 217 out of bounds for feature rolling_6h_max_t-161. Skipping.
# Warning: Index 2972 out of bounds for feature change_rate_1h_t-75. Skipping.
# Warning: Index 343 out of bounds for feature lag_168h_t-157. Skipping.
# Warning: Index 4697 out of bounds for feature rolling_6h_max_t-21. Skipping.
# Warning: Index 3897 out of bounds for feature rolling_6h_max_t-46. Skipping.
# Warning: Index 2686 out of bounds for feature delta_24h_t-84. Skipping.
# Warning: Index 4211 out of bounds for feature lag_1h_t-36. Skipping.
# Warning: Index 1054 out of bounds for feature delta_24h_t-135. Skipping.
# Warning: Index 3233 out of bounds for feature precipitation_t-66. Skipping.
# Warning: Index 403 out of bounds for feature lag_1h_t-155. Skipping.
# Warning: Index 2233 out of bounds for feature rolling_6h_max_t-98. Skipping.
# Warning: Index 3814 out of bounds for feature input_t-48. Skipping.
# Warning: Index 1666 out of bounds for feature wind_speed_t-115. Skipping.
# Warning: Index 508 out of bounds for feature change_rate_1h_t-152. Skipping.
# Warning: Index 1826 out of bounds for feature wind_speed_t-110. Skipping.
# Warning: Index 2656 out of bounds for feature temperature_t-84. Skipping.
# Warning: Index 702 out of bounds for feature delta_24h_t-146. Skipping.
# Warning: Index 3746 out of bounds for feature wind_speed_t-50. Skipping.
# Warning: Index 4793 out of bounds for feature rolling_6h_max_t-18. Skipping.
# Warning: Index 1122 out of bounds for feature wind_speed_t-132. Skipping.
# Warning: Index 5180 out of bounds for feature change_rate_1h_t-6. Skipping.
# Warning: Index 4409 out of bounds for feature rolling_6h_max_t-30. Skipping.
# Warning: Index 54 out of bounds for feature lag_24h_t-166. Skipping.
# Warning: Index 990 out of bounds for feature delta_24h_t-137. Skipping.
# Warning: Index 2630 out of bounds for feature input_t-85. Skipping.
# Warning: Index 1209 out of bounds for feature rolling_6h_max_t-130. Skipping.
# Warning: Index 1815 out of bounds for feature lag_168h_t-111. Skipping.
# Warning: Index 1318 out of bounds for feature input_t-126. Skipping.
# Warning: Index 286 out of bounds for feature delta_24h_t-159. Skipping.
# Warning: Index 2131 out of bounds for feature lag_1h_t-101. Skipping.
# Warning: Index 3996 out of bounds for feature change_rate_1h_t-43. Skipping.
# Warning: Index 1478 out of bounds for feature input_t-121. Skipping.
# Warning: Index 534 out of bounds for feature lag_24h_t-151. Skipping.
# Warning: Index 413 out of bounds for feature rolling_7d_std_t-155. Skipping.
# Warning: Index 1847 out of bounds for feature lag_168h_t-110. Skipping.
# Warning: Index 4134 out of bounds for feature input_t-38. Skipping.
# Warning: Index 1631 out of bounds for feature daily_range_lag_1d_t-117. Skipping.
# Warning: Index 2492 out of bounds for feature change_rate_1h_t-90. Skipping.
# Warning: Index 1281 out of bounds for feature precipitation_t-127. Skipping.
# Warning: Index 2355 out of bounds for feature lag_1h_t-94. Skipping.
# Warning: Index 311 out of bounds for feature lag_168h_t-158. Skipping.
# Warning: Index 4371 out of bounds for feature lag_1h_t-31. Skipping.
# Warning: Index 1532 out of bounds for feature change_rate_1h_t-120. Skipping.
# Warning: Index 2743 out of bounds for feature lag_168h_t-82. Skipping.
# Warning: Index 3315 out of bounds for feature lag_1h_t-64. Skipping.
# Warning: Index 958 out of bounds for feature delta_24h_t-138. Skipping.
# Warning: Index 2622 out of bounds for feature delta_24h_t-86. Skipping.
# Warning: Index 5144 out of bounds for feature rolling_3h_avg_t-7. Skipping.
# Warning: Index 418 out of bounds for feature wind_speed_t-154. Skipping.
# Warning: Index 668 out of bounds for feature change_rate_1h_t-147. Skipping.
# Warning: Index 1817 out of bounds for feature rolling_6h_max_t-111. Skipping.
# Warning: Index 2455 out of bounds for feature lag_168h_t-91. Skipping.
# Warning: Index 88 out of bounds for feature rolling_3h_avg_t-165. Skipping.
# Warning: Index 3583 out of bounds for feature daily_range_lag_1d_t-56. Skipping.
# Warning: Index 4579 out of bounds for feature humidity_t-24. Skipping.
# Warning: Index 4576 out of bounds for feature temperature_t-24. Skipping.
# Warning: Index 2433 out of bounds for feature precipitation_t-91. Skipping.
# Warning: Index 4253 out of bounds for feature rolling_7d_std_t-35. Skipping.
# Warning: Index 774 out of bounds for feature input_t-143. Skipping.
# Warning: Index 4736 out of bounds for feature temperature_t-19. Skipping.
# Warning: Index 1655 out of bounds for feature lag_168h_t-116. Skipping.
# Warning: Index 1527 out of bounds for feature lag_168h_t-120. Skipping.
# Warning: Index 2398 out of bounds for feature delta_24h_t-93. Skipping.
# Warning: Index 1651 out of bounds for feature lag_1h_t-116. Skipping.
# Warning: Index 2780 out of bounds for feature change_rate_1h_t-81. Skipping.
# Warning: Index 2746 out of bounds for feature rolling_6h_avg_t-82. Skipping.
# Warning: Index 4550 out of bounds for feature input_t-25. Skipping.
# Warning: Index 1309 out of bounds for feature rolling_7d_std_t-127. Skipping.
# Warning: Index 3132 out of bounds for feature change_rate_1h_t-70. Skipping.
# Warning: Index 3292 out of bounds for feature change_rate_1h_t-65. Skipping.
# Warning: Index 1271 out of bounds for feature lag_168h_t-128. Skipping.
# Warning: Index 221 out of bounds for feature rolling_7d_std_t-161. Skipping.
# Warning: Index 1692 out of bounds for feature change_rate_1h_t-115. Skipping.
# Warning: Index 2424 out of bounds for feature rolling_3h_avg_t-92. Skipping.
# Warning: Index 5126 out of bounds for feature input_t-7. Skipping.
# Warning: Index 4888 out of bounds for feature rolling_3h_avg_t-15. Skipping.
# Warning: Index 706 out of bounds for feature wind_speed_t-145. Skipping.
# Warning: Index 1048 out of bounds for feature rolling_3h_avg_t-135. Skipping.
# Warning: Index 3998 out of bounds for feature delta_24h_t-43. Skipping.
# Warning: Index 5060 out of bounds for feature atmospheric_pressure_t-9. Skipping.
# Warning: Index 1564 out of bounds for feature change_rate_1h_t-119. Skipping.
# Warning: Index 1920 out of bounds for feature temperature_t-107. Skipping.
# Warning: Index 1534 out of bounds for feature delta_24h_t-120. Skipping.
# Warning: Index 449 out of bounds for feature precipitation_t-153. Skipping.
# Warning: Index 4038 out of bounds for feature input_t-41. Skipping.
# Warning: Index 4706 out of bounds for feature wind_speed_t-20. Skipping.
# Warning: Index 2728 out of bounds for feature dayofweek_t-82. Skipping.
# Warning: Index 2908 out of bounds for feature change_rate_1h_t-77. Skipping.
# Warning: Index 2748 out of bounds for feature change_rate_1h_t-82. Skipping.
# Warning: Index 1107 out of bounds for feature lag_1h_t-133. Skipping.
# Warning: Index 1788 out of bounds for feature change_rate_1h_t-112. Skipping.
# Warning: Index 3868 out of bounds for feature change_rate_1h_t-47. Skipping.
# Warning: Index 1715 out of bounds for feature lag_1h_t-114. Skipping.
# Warning: Index 4595 out of bounds for feature lag_1h_t-24. Skipping.
# Warning: Index 1346 out of bounds for feature wind_speed_t-125. Skipping.
# Warning: Index 94 out of bounds for feature delta_24h_t-165. Skipping.
# Warning: Index 2462 out of bounds for feature delta_24h_t-91. Skipping.
# Warning: Index 4128 out of bounds for feature temperature_t-38. Skipping.
# Warning: Index 1555 out of bounds for feature lag_1h_t-119. Skipping.
# Warning: Index 3454 out of bounds for feature delta_24h_t-60. Skipping.
# Warning: Index 505 out of bounds for feature rolling_6h_max_t-152. Skipping.
# Warning: Index 3964 out of bounds for feature change_rate_1h_t-44. Skipping.
# Warning: Index 1850 out of bounds for feature rolling_6h_avg_t-110. Skipping.
# Warning: Index 4732 out of bounds for feature change_rate_1h_t-20. Skipping.
# Warning: Index 3843 out of bounds for feature humidity_t-47. Skipping.
# Warning: Index 342 out of bounds for feature lag_24h_t-157. Skipping.
# Warning: Index 1495 out of bounds for feature lag_168h_t-121. Skipping.
# Warning: Index 4703 out of bounds for feature daily_range_lag_1d_t-21. Skipping.
# Warning: Index 4254 out of bounds for feature delta_24h_t-35. Skipping.
# Warning: Index 482 out of bounds for feature wind_speed_t-152. Skipping.
# Warning: Index 1086 out of bounds for feature delta_24h_t-134. Skipping.
# Warning: Index 1691 out of bounds for feature rolling_24h_max_t-115. Skipping.
# Warning: Index 3171 out of bounds for feature humidity_t-68. Skipping.
# Warning: Index 4700 out of bounds for feature change_rate_1h_t-21. Skipping.
# Selected feature X train shape: (9674, 168, 7)
# Selected feature X valid shape: (1074, 168, 7)
# Selected feature X test shape: (4607, 168, 7)

# %%
reg_selected = xgb.XGBRegressor(n_estimators=1000, eval_metric="rmse", random_state=1021, early_stopping_rounds=25)
reg_selected.fit(
  X_train_selected.reshape(X_train_selected.shape[0], -1), 
  y_train.reshape(-1),
  eval_set=[(X_valid_selected.reshape(X_valid_selected.shape[0], -1), y_valid.reshape(-1))],
  verbose=10,
)
# Out:
# [0]	validation_0-rmse:2085.89206
# [10]	validation_0-rmse:1431.11884
# [20]	validation_0-rmse:1436.20241
# [30]	validation_0-rmse:1437.65337
# [37]	validation_0-rmse:1442.33619
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=25,
#              enable_categorical=False, eval_metric='rmse', feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=1000, n_jobs=None,
#              num_parallel_tree=None, random_state=1021, ...)

# %%
y_pred_selected = reg_selected.predict(X_test_selected.reshape(X_test_selected.shape[0], -1))
rmse_selected = np.sqrt(mean_squared_error(y_test, y_pred_selected))

print(f"Test RMSE with selected features: {rmse_selected}")

y_pred_all = reg_all.predict(X_test.reshape(X_test.shape[0], -1))
rmse_all = np.sqrt(mean_squared_error(y_test, y_pred_all))

print(f"Test RMSE with all features: {rmse_all}")
# Out:
# Test RMSE with selected features: 1534.3167348375937
# Test RMSE with all features: 1499.1792705326693

# %%
def evaluate_model_cv(X, y, n_splits=5):
  kf = KFold(n_splits=n_splits, shuffle=True, random_state=42)
  rmse_scores = []
  
  for train_index, val_index in kf.split(X):
    X_train_cv, X_val_cv = X[train_index], X[val_index]
    y_train_cv, y_val_cv = y[train_index], y[val_index]
    
    reg_cv = xgb.XGBRegressor(n_estimators=1000, eval_metric="rmse", random_state=42)
    reg_cv.fit(
      X_train_cv.reshape(X_train_cv.shape[0], -1), 
      y_train_cv.reshape(-1),
      eval_set=[(X_val_cv.reshape(X_val_cv.shape[0], -1), y_val_cv.reshape(-1))],
      verbose=False,
      early_stopping_rounds=50
    )
    
    y_pred_cv = reg_cv.predict(X_val_cv.reshape(X_val_cv.shape[0], -1))
    rmse_cv = np.sqrt(mean_squared_error(y_val_cv, y_pred_cv))
    rmse_scores.append(rmse_cv)
      
  return np.mean(rmse_scores)

# # 선택된 feature로 교차 검증 수행
# rmse_cv_selected = evaluate_model_cv(X_train_selected, y_train)
# print(f"Cross-validation RMSE with selected features: {rmse_cv_selected}")

# # 모든 feature로 교차 검증 수행
# rmse_cv_all = evaluate_model_cv(X_train, y_train)
# print(f"Cross-validation RMSE with all features: {rmse_cv_all}")

# %%
model_filename = './model/1hour_xgboost_selected_features_model.json'
reg_selected.save_model(model_filename)

# %%
model_filename2 = './model/1hour_xgboost_all_features_model.json'
reg_all.save_model(model_filename2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 model_filename2 = './model/1hour_xgboost_all_features_model.json'
# ----> 2 reg_all.save_model(model_filename2)
#
# NameError: name 'reg_all' is not defined

# %%
model = xgb.Booster(model_file=model_filename2)

# %%
data = pd.read_csv('./data/j_before_feature_importance_with_datetime.csv')

# %%
# 예측을 위한 DMatrix 생성
dtest = xgb.DMatrix(X_test.reshape(X_test.shape[0], -1))

# 예측 수행
y_pred = model.predict(dtest)

# %%
from sklearn.metrics import mean_squared_error, r2_score
def mean_absolute_percentage_error(y_true, y_pred):
  y_true, y_pred = np.array(y_true), np.array(y_pred)
  return np.mean(np.abs((y_true - y_pred) / y_true)) * 100


rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
print(f'Test RMSE: {rmse:.4f}')
print(f'Test MAPE: {mape:.4f}%')
print(f'Test R-squared: {r2:.4f}')
# Out:
# Test RMSE: 1512.5276
# Test MAPE: 30.0959%
# Test R-squared: 0.6511

# %%
# 시각화
plt.figure(figsize=(20, 8))

# datetime 정보 추출
start_index = train_size + SEQ_LENGTH  # X_test 시작 위치
end_index = start_index + len(y_test) # X_test 끝 위치

# datetime 범위 생성
datetime_range = data['datetime'][start_index:end_index].values
if len(datetime_range) < len(y_pred):
  print("Warning: Datetime range is shorter than prediction length. Adjusting range.")
  y_pred = y_pred[:len(datetime_range)]

# y_test의 범위도 조정
y_test_plot = y_test[:len(datetime_range)]

# 시각화
plt.plot(datetime_range, y_test_plot, label='Actual')
plt.plot(datetime_range, y_pred, label='Predicted')

plt.xticks([])  # x축 눈금 제거
plt.xlabel('Datetime')
plt.ylabel('Outflow')
plt.title('Actual vs Predicted Outflow')
plt.legend()
plt.tight_layout()        # 레이아웃 조정
plt.show()

# %%
def plot_predictions_weekly(y_true, y_pred, datetime_data, start_index, plot_title):
  plt.figure(figsize=(20, 6))

  # datetime 범위 추출
  datetime_range = datetime_data[start_index:start_index + 168].values  # 일주일 (168시간)

  # 예측값과 실제값 범위 조정
  y_true_plot = y_true[:168]
  y_pred_plot = y_pred[:168]

  plt.plot(y_true_plot, label='Actual')
  plt.plot(y_pred_plot, label='Predicted')

  plt.xlabel('Datetime')
  plt.ylabel('Outflow')
  plt.title(plot_title)
  plt.legend()
  plt.xticks([])  # x축 레이블 생략
  plt.tight_layout()
  plt.show()

# 초반 일주일 시각화
start_index_start = train_size + SEQ_LENGTH
plot_predictions_weekly(y_test, y_pred, data['datetime'], start_index_start, 'First Week Predictions')

# 마지막 일주일 시각화
start_index_end = train_size + SEQ_LENGTH + len(y_test) - 168 # 마지막 168시간을 맞추기 위해 index 조정
plot_predictions_weekly(y_test[-168:], y_pred[-168:], data['datetime'], len(data) - 168, 'Last Week Predictions')
